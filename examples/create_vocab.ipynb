# %%
vocab = set()
with open('google_sp.vocab', 'r') as f:
    for line in f.readlines():
        vocab.add(line[0])
        
vocab = list(vocab)
print(vocab[100:120])
print(len(vocab))
# Out:
# ['寧', '子', '多', '薬', '諷', '批', '約', '室', '咄', '咀', '直', '翻', '巣', '戌', 'ツ', '九', '艤', 'ы', '位', '圧']
# 3901

# %%
from util.data_processing import save_labels
